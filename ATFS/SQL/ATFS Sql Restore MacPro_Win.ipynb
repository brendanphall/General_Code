# %%
import pyodbc

def test_sql_connection():
    try:
        conn = pyodbc.connect(
            r'DRIVER={ODBC Driver 17 for SQL Server};'
            r'SERVER=localhost\sqlexpress;'
            r'Trusted_Connection=yes;'
        )
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sys.databases")
        print("✅ Connection successful. Databases found:")
        for row in cursor.fetchall():
            print(f" - {row.name}")
        conn.close()
    except Exception as e:
        print("❌ Connection failed:")
        print(e)

if __name__ == "__main__":
    test_sql_connection()
# Out:
# ✅ Connection successful. Databases found:
#  - master
#  - tempdb
#  - model
#  - msdb

# %%
import os
import subprocess
import time
from pathlib import Path
import pyodbc

# === Configuration ===
sql_server_instance = r"BRENDANHALL2D11\SQL_MACPRO_MAUTH"
restore_script_path = Path(r"C:\Temp\ATFS\restore_local_BPH.sql")
backup_dir = Path(r"C:\Temp\ATFS\atfs_bak_20250408_020000")
delete_after = False  # Set to True to auto-delete .bak files after restore

backup_files = [
    backup_dir / "atfs.bak",
    backup_dir / "atfs_log.bak",
    backup_dir / "atfs_gdb.bak",
    backup_dir / "atfs_gdb_log.bak"
]

# === Drop database if exists ===
def drop_db_if_exists(server, db_name):
    try:
        conn = pyodbc.connect(
            rf'DRIVER={{ODBC Driver 17 for SQL Server}};SERVER={server};Trusted_Connection=yes;',
            autocommit=True
        )
        cursor = conn.cursor()

        # Check if DB exists
        cursor.execute("SELECT name FROM sys.databases WHERE LOWER(name) = LOWER(?)", (db_name,))
        if cursor.fetchone():
            print(f"⚠️  Dropping existing database '{db_name}'...")

            # Kill active sessions
            cursor.execute(f"""
                DECLARE @kill varchar(8000) = '';
                SELECT @kill = @kill + 'KILL ' + CONVERT(varchar(5), session_id) + ';'
                FROM sys.dm_exec_sessions
                WHERE database_id = DB_ID('{db_name}') AND session_id <> @@SPID;
                EXEC(@kill);
            """)

            # Drop the database
            cursor.execute(f"ALTER DATABASE [{db_name}] SET SINGLE_USER WITH ROLLBACK IMMEDIATE;")
            cursor.execute(f"DROP DATABASE [{db_name}];")
            print(f"✅ Dropped '{db_name}'.")
        else:
            print(f"ℹ️  Database '{db_name}' does not exist.")
        conn.close()
    except Exception as e:
        print(f"❌ Error dropping database '{db_name}': {e}")

# === Run SQL restore script via sqlcmd ===
def run_sqlcmd(script_path):
    try:
        print("🚀 Restoring databases from script...")
        start = time.time()

        result = subprocess.run([
            "sqlcmd",
            "-S", sql_server_instance,
            "-E",
            "-i", str(script_path),
            "-b"  # stop on first error
        ], capture_output=True, text=True)

        duration = time.time() - start

        print("📤 SQLCMD OUTPUT:")
        print(result.stdout)

        if result.stderr:
            print("❌ SQLCMD ERRORS:")
            print(result.stderr)

        if result.returncode == 0:
            print(f"✅ Restore complete in {duration:.2f} seconds.")
        else:
            print(f"⚠️ sqlcmd exited with return code {result.returncode}. Check above for errors.")

    except subprocess.CalledProcessError as e:
        print("❌ sqlcmd failed:", e)

# === Delete .bak files ===
def delete_files(paths):
    for path in paths:
        try:
            if path.exists():
                path.unlink()
                print(f"🗑️  Deleted: {path}")
            else:
                print(f"📁 Not found (skipped): {path}")
        except Exception as e:
            print(f"⚠️  Could not delete {path}: {e}")

# === Main workflow ===
def main():
    print("🔍 Verifying script and backup files...")

    if not restore_script_path.exists():
        print(f"❌ Restore script not found: {restore_script_path}")
        return

    missing = [f for f in backup_files if not f.exists()]
    if missing:
        print("❌ Missing required backup files:")
        for f in missing:
            print(f" - {f}")
        return

    # Drop if already exists
    drop_db_if_exists(sql_server_instance, "atfs")
    drop_db_if_exists(sql_server_instance, "atfs_gdb")

    # Run restore
    run_sqlcmd(restore_script_path)

    # Optional: delete .bak files
    if delete_after:
        delete_files(backup_files)

    print("✅ All operations complete.")

if __name__ == "__main__":
    main()
# Out:
# 🔍 Verifying script and backup files...
# ⚠️  Dropping existing database 'atfs'...
# ✅ Dropped 'atfs'.
# ⚠️  Dropping existing database 'atfs_gdb'...
# ✅ Dropped 'atfs_gdb'.
# 🚀 Restoring databases from script...
# 📤 SQLCMD OUTPUT:
# Changed database context to 'master'.
# ƒo. Starting restore for [atfs]...
# Processed 276496 pages for database 'atfs', file 'atfs' on file 1.
# Processed 3 pages for database 'atfs', file 'atfs_log' on file 1.
# Converting database 'atfs' from version 869 to the current version 957.
# Database 'atfs' running the upgrade step from version 869 to version 875.
# Database 'atfs' running the upgrade step from version 875 to version 876.
# Database 'atfs' running the upgrade step from version 876 to version 877.
# Database 'atfs' running the upgrade step from version 877 to version 878.
# Database 'atfs' running the upgrade step from version 878 to version 879.
# Database 'atfs' running the upgrade step from version 879 to version 880.
# Database 'atfs' running the upgrade step from version 880 to version 881.
# Database 'atfs' running the upgrade step from version 881 to version 882.
# Database 'atfs' running the upgrade step from version 882 to version 883.
# Database 'atfs' running the upgrade step from version 883 to version 884.
# Database 'atfs' running the upgrade step from version 884 to version 885.
# Database 'atfs' running the upgrade step from version 885 to version 886.
# Database 'atfs' running the upgrade step from version 886 to version 887.
# Database 'atfs' running the upgrade step from version 887 to version 888.
# Database 'atfs' running the upgrade step from version 888 to version 889.
# Database 'atfs' running the upgrade step from version 889 to version 890.
# Database 'atfs' running the upgrade step from version 890 to version 891.
# Database 'atfs' running the upgrade step from version 891 to version 892.
# Database 'atfs' running the upgrade step from version 892 to version 893.
# Database 'atfs' running the upgrade step from version 893 to version 894.
# Database 'atfs' running the upgrade step from version 894 to version 895.
# Database 'atfs' running the upgrade step from version 895 to version 896.
# Database 'atfs' running the upgrade step from version 896 to version 897.
# Database 'atfs' running the upgrade step from version 897 to version 898.
# Database 'atfs' running the upgrade step from version 898 to version 899.
# Database 'atfs' running the upgrade step from version 899 to version 900.
# Database 'atfs' running the upgrade step from version 900 to version 901.
# Database 'atfs' running the upgrade step from version 901 to version 902.
# Database 'atfs' running the upgrade step from version 902 to version 903.
# Database 'atfs' running the upgrade step from version 903 to version 904.
# Database 'atfs' running the upgrade step from version 904 to version 905.
# Database 'atfs' running the upgrade step from version 905 to version 906.
# Database 'atfs' running the upgrade step from version 906 to version 907.
# Database 'atfs' running the upgrade step from version 907 to version 908.
# Database 'atfs' running the upgrade step from version 908 to version 909.
# Database 'atfs' running the upgrade step from version 909 to version 910.
# Database 'atfs' running the upgrade step from version 910 to version 911.
# Database 'atfs' running the upgrade step from version 911 to version 912.
# Database 'atfs' running the upgrade step from version 912 to version 913.
# Database 'atfs' running the upgrade step from version 913 to version 914.
# Database 'atfs' running the upgrade step from version 914 to version 915.
# Database 'atfs' running the upgrade step from version 915 to version 916.
# Database 'atfs' running the upgrade step from version 916 to version 917.
# Database 'atfs' running the upgrade step from version 917 to version 918.
# Database 'atfs' running the upgrade step from version 918 to version 919.
# Database 'atfs' running the upgrade step from version 919 to version 920.
# Database 'atfs' running the upgrade step from version 920 to version 921.
# Database 'atfs' running the upgrade step from version 921 to version 922.
# Database 'atfs' running the upgrade step from version 922 to version 923.
# Database 'atfs' running the upgrade step from version 923 to version 924.
# Database 'atfs' running the upgrade step from version 924 to version 925.
# Database 'atfs' running the upgrade step from version 925 to version 926.
# Database 'atfs' running the upgrade step from version 926 to version 927.
# Database 'atfs' running the upgrade step from version 927 to version 928.
# Database 'atfs' running the upgrade step from version 928 to version 929.
# Database 'atfs' running the upgrade step from version 929 to version 930.
# Database 'atfs' running the upgrade step from version 930 to version 931.
# Database 'atfs' running the upgrade step from version 931 to version 932.
# Database 'atfs' running the upgrade step from version 932 to version 933.
# Database 'atfs' running the upgrade step from version 933 to version 934.
# Database 'atfs' running the upgrade step from version 934 to version 935.
# Database 'atfs' running the upgrade step from version 935 to version 936.
# Database 'atfs' running the upgrade step from version 936 to version 937.
# Database 'atfs' running the upgrade step from version 937 to version 938.
# Database 'atfs' running the upgrade step from version 938 to version 939.
# Database 'atfs' running the upgrade step from version 939 to version 940.
# Database 'atfs' running the upgrade step from version 940 to version 941.
# Database 'atfs' running the upgrade step from version 941 to version 942.
# Database 'atfs' running the upgrade step from version 942 to version 943.
# Database 'atfs' running the upgrade step from version 943 to version 944.
# Database 'atfs' running the upgrade step from version 944 to version 945.
# Database 'atfs' running the upgrade step from version 945 to version 946.
# Database 'atfs' running the upgrade step from version 946 to version 947.
# Database 'atfs' running the upgrade step from version 947 to version 948.
# Database 'atfs' running the upgrade step from version 948 to version 949.
# Database 'atfs' running the upgrade step from version 949 to version 950.
# Database 'atfs' running the upgrade step from version 950 to version 951.
# Database 'atfs' running the upgrade step from version 951 to version 952.
# Database 'atfs' running the upgrade step from version 952 to version 953.
# Database 'atfs' running the upgrade step from version 953 to version 954.
# Database 'atfs' running the upgrade step from version 954 to version 955.
# Database 'atfs' running the upgrade step from version 955 to version 956.
# Database 'atfs' running the upgrade step from version 956 to version 957.
# RESTORE DATABASE successfully processed 276499 pages in 5.090 seconds (424.390 MB/sec).
# Changed database context to 'atfs'.
# The row for user 'atfs' will be fixed by updating its login link to a login already in existence.
# The number of orphaned users fixed by updating users was 1.
# The number of orphaned users fixed by adding new logins and then updating users was 0.
# Changed database context to 'master'.
# ƒo. Starting restore for [atfs_gdb]...
# 10 percent processed.
# 20 percent processed.
# 30 percent processed.
# 40 percent processed.
# 50 percent processed.
# 60 percent processed.
# 70 percent processed.
# 80 percent processed.
# 90 percent processed.
# 100 percent processed.
# Processed 37368 pages for database 'atfs_gdb', file 'atfs_gdb' on file 1.
# Processed 2 pages for database 'atfs_gdb', file 'atfs_gdb_log' on file 1.
# Converting database 'atfs_gdb' from version 869 to the current version 957.
# Database 'atfs_gdb' running the upgrade step from version 869 to version 875.
# Database 'atfs_gdb' running the upgrade step from version 875 to version 876.
# Database 'atfs_gdb' running the upgrade step from version 876 to version 877.
# Database 'atfs_gdb' running the upgrade step from version 877 to version 878.
# Database 'atfs_gdb' running the upgrade step from version 878 to version 879.
# Database 'atfs_gdb' running the upgrade step from version 879 to version 880.
# Database 'atfs_gdb' running the upgrade step from version 880 to version 881.
# Database 'atfs_gdb' running the upgrade step from version 881 to version 882.
# Database 'atfs_gdb' running the upgrade step from version 882 to version 883.
# Database 'atfs_gdb' running the upgrade step from version 883 to version 884.
# Database 'atfs_gdb' running the upgrade step from version 884 to version 885.
# Database 'atfs_gdb' running the upgrade step from version 885 to version 886.
# Database 'atfs_gdb' running the upgrade step from version 886 to version 887.
# Database 'atfs_gdb' running the upgrade step from version 887 to version 888.
# Database 'atfs_gdb' running the upgrade step from version 888 to version 889.
# Database 'atfs_gdb' running the upgrade step from version 889 to version 890.
# Database 'atfs_gdb' running the upgrade step from version 890 to version 891.
# Database 'atfs_gdb' running the upgrade step from version 891 to version 892.
# Database 'atfs_gdb' running the upgrade step from version 892 to version 893.
# Database 'atfs_gdb' running the upgrade step from version 893 to version 894.
# Database 'atfs_gdb' running the upgrade step from version 894 to version 895.
# Database 'atfs_gdb' running the upgrade step from version 895 to version 896.
# Database 'atfs_gdb' running the upgrade step from version 896 to version 897.
# Database 'atfs_gdb' running the upgrade step from version 897 to version 898.
# Database 'atfs_gdb' running the upgrade step from version 898 to version 899.
# Database 'atfs_gdb' running the upgrade step from version 899 to version 900.
# Database 'atfs_gdb' running the upgrade step from version 900 to version 901.
# Database 'atfs_gdb' running the upgrade step from version 901 to version 902.
# Database 'atfs_gdb' running the upgrade step from version 902 to version 903.
# Database 'atfs_gdb' running the upgrade step from version 903 to version 904.
# Database 'atfs_gdb' running the upgrade step from version 904 to version 905.
# Database 'atfs_gdb' running the upgrade step from version 905 to version 906.
# Database 'atfs_gdb' running the upgrade step from version 906 to version 907.
# Database 'atfs_gdb' running the upgrade step from version 907 to version 908.
# Database 'atfs_gdb' running the upgrade step from version 908 to version 909.
# Database 'atfs_gdb' running the upgrade step from version 909 to version 910.
# Database 'atfs_gdb' running the upgrade step from version 910 to version 911.
# Database 'atfs_gdb' running the upgrade step from version 911 to version 912.
# Database 'atfs_gdb' running the upgrade step from version 912 to version 913.
# Database 'atfs_gdb' running the upgrade step from version 913 to version 914.
# Database 'atfs_gdb' running the upgrade step from version 914 to version 915.
# Database 'atfs_gdb' running the upgrade step from version 915 to version 916.
# Database 'atfs_gdb' running the upgrade step from version 916 to version 917.
# Database 'atfs_gdb' running the upgrade step from version 917 to version 918.
# Database 'atfs_gdb' running the upgrade step from version 918 to version 919.
# Database 'atfs_gdb' running the upgrade step from version 919 to version 920.
# Database 'atfs_gdb' running the upgrade step from version 920 to version 921.
# Database 'atfs_gdb' running the upgrade step from version 921 to version 922.
# Database 'atfs_gdb' running the upgrade step from version 922 to version 923.
# Database 'atfs_gdb' running the upgrade step from version 923 to version 924.
# Database 'atfs_gdb' running the upgrade step from version 924 to version 925.
# Database 'atfs_gdb' running the upgrade step from version 925 to version 926.
# Database 'atfs_gdb' running the upgrade step from version 926 to version 927.
# Database 'atfs_gdb' running the upgrade step from version 927 to version 928.
# Database 'atfs_gdb' running the upgrade step from version 928 to version 929.
# Database 'atfs_gdb' running the upgrade step from version 929 to version 930.
# Database 'atfs_gdb' running the upgrade step from version 930 to version 931.
# Database 'atfs_gdb' running the upgrade step from version 931 to version 932.
# Database 'atfs_gdb' running the upgrade step from version 932 to version 933.
# Database 'atfs_gdb' running the upgrade step from version 933 to version 934.
# Database 'atfs_gdb' running the upgrade step from version 934 to version 935.
# Database 'atfs_gdb' running the upgrade step from version 935 to version 936.
# Database 'atfs_gdb' running the upgrade step from version 936 to version 937.
# Database 'atfs_gdb' running the upgrade step from version 937 to version 938.
# Database 'atfs_gdb' running the upgrade step from version 938 to version 939.
# Database 'atfs_gdb' running the upgrade step from version 939 to version 940.
# Database 'atfs_gdb' running the upgrade step from version 940 to version 941.
# Database 'atfs_gdb' running the upgrade step from version 941 to version 942.
# Database 'atfs_gdb' running the upgrade step from version 942 to version 943.
# Database 'atfs_gdb' running the upgrade step from version 943 to version 944.
# Database 'atfs_gdb' running the upgrade step from version 944 to version 945.
# Database 'atfs_gdb' running the upgrade step from version 945 to version 946.
# Database 'atfs_gdb' running the upgrade step from version 946 to version 947.
# Database 'atfs_gdb' running the upgrade step from version 947 to version 948.
# Database 'atfs_gdb' running the upgrade step from version 948 to version 949.
# Database 'atfs_gdb' running the upgrade step from version 949 to version 950.
# Database 'atfs_gdb' running the upgrade step from version 950 to version 951.
# Database 'atfs_gdb' running the upgrade step from version 951 to version 952.
# Database 'atfs_gdb' running the upgrade step from version 952 to version 953.
# Database 'atfs_gdb' running the upgrade step from version 953 to version 954.
# Database 'atfs_gdb' running the upgrade step from version 954 to version 955.
# Database 'atfs_gdb' running the upgrade step from version 955 to version 956.
# Database 'atfs_gdb' running the upgrade step from version 956 to version 957.
# RESTORE DATABASE successfully processed 37370 pages in 0.529 seconds (551.886 MB/sec).
# Changed database context to 'atfs_gdb'.
# The number of orphaned users fixed by updating users was 0.
# The number of orphaned users fixed by adding new logins and then updating users was 0.
# Processed 276680 pages for database 'atfs', file 'atfs' on file 1.
# Processed 2 pages for database 'atfs', file 'atfs_log' on file 1.
# BACKUP DATABASE successfully processed 276682 pages in 1.683 seconds (1284.357 MB/sec).
# Processed 37448 pages for database 'atfs_gdb', file 'atfs_gdb' on file 1.
# Processed 2 pages for database 'atfs_gdb', file 'atfs_gdb_log' on file 1.
# BACKUP DATABASE successfully processed 37450 pages in 0.266 seconds (1099.903 MB/sec).
# Changed database context to 'atfs'.
# DbId   FileId      CurrentSize MinimumSize UsedPages   EstimatedPages
# ------ ----------- ----------- ----------- ----------- --------------
#      5           2       13088         128       13088            128
#
# (1 rows affected)
# DBCC execution completed. If DBCC printed error messages, contact your system administrator.
# DbId   FileId      CurrentSize MinimumSize UsedPages   EstimatedPages
# ------ ----------- ----------- ----------- ----------- --------------
#      5           1      275856         256      270384         270384
#
# (1 rows affected)
# DBCC execution completed. If DBCC printed error messages, contact your system administrator.
#
# ✅ Restore complete in 77.70 seconds.
# ✅ All operations complete.
